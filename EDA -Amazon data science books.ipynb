# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
dataset = pd.read_csv("/content/drive/MyDrive/final_book_dataset_kaggle.csv")
dataset
# Out:
#                                                  title  \
# 0    Becoming a Data Head: How to Think Speak and U...
# 1    Ace the Data Science Interview: 201 Real Inter...
# 2    Fundamentals of Data Engineering: Plan and Bui...
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 0          [Alex J. Gutman,Jordan Goldmeier]   24.49  272.0          4.6
# 1                     [Nick Singh,Kevin Huo]   26.00  301.0          4.5
# 2                    [Joe Reis,Matt Housley]   50.76  446.0          5.0
# ...

# %% [markdown]
# # Exporatory data analysis

# %% [markdown]
# **Price VS reviews**

# %%
dataset.info() 
#Print a concise summary of a DataFrame.This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          946 non-null    object
#  1   author         824 non-null    object
#  2   price          944 non-null    float64
#  3   pages          934 non-null    float64
#  4   avg_reviews    823 non-null    float64
#  5   n_reviews      946 non-null    int64
#  6   star5          946 non-null    float64
#  7   star4          946 non-null    float64
#  8   star3          946 non-null    float64
#  9   star2          946 non-null    float64
#  10  star1          946 non-null    float64
#  11  dimensions     914 non-null    object
#  12  weight         943 non-null    object
#  13  language       943 non-null    object
#  14  publisher      942 non-null    object
#  15  ISBN_13        945 non-null    object
#  16  link           946 non-null    object
# ...

# %%
dataset.describe()
#Analyzes both numeric and object series, as well as DataFrame column sets of mixed data type.The describe() method returns description of the data in the DataFrame, as given below
# Out:
#             price        pages  avg_reviews    n_reviews       star5  \
# count  944.000000   934.000000   823.000000   946.000000  946.000000
# mean    52.103528   419.356531     4.442163   137.754757    0.625603
# std     36.590725   203.984911     0.401256   499.485754    0.279219
# min      4.730000    48.000000     1.000000     0.000000    0.000000
# 25%     31.907500   272.000000     4.300000     5.000000    0.570000
# 50%     43.985000   384.000000     4.500000    25.000000    0.700000
# 75%     56.765000   531.500000     4.700000    91.000000    0.780000
# max    279.950000  1728.000000     5.000000  7563.000000    1.000000
#
#             star4       star3       star2       star1
# count  946.000000  946.000000  946.000000  946.000000
# mean     0.140835    0.058192    0.026575    0.018732
# std      0.113105    0.061997    0.038293    0.032132
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.070000    0.000000    0.000000    0.000000
# ...

# %%
fig = px.scatter(dataset, x = "price", y = "pages", size = "n_reviews")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
py_books = dataset[dataset['title'].str.contains('python')]
py_books
# Best pyhton books with respect to number of reviews and average reviews.
best_pythonbook = py_books.nlargest(2, ['n_reviews', 'avg_reviews'])
best_pythonbook
# Out:
#                                                  title           author  \
# 371  Python: 3 books in 1- Your complete guide to p...  [Brady Ellison]
# 802  Python for Data Analysis: A Beginners Guide to...              NaN
#
#      price  pages  avg_reviews  n_reviews  star5  star4  star3  star2  star1  \
# 371  24.95  472.0          4.7        119   0.82   0.10   0.04   0.02   0.01
# 802  17.97  173.0          4.3         30   0.61   0.14   0.20   0.05   0.00
#
#               dimensions       weight language  \
# 371  6 x 1.07 x 9 inches  1.63 pounds  English
# 802  6 x 0.39 x 9 inches   9.1 ounces  English
#
#                                      publisher         ISBN_13  \
# 371  Independently published (February 4 2022)  979-8410695930
# 802   Independently published (August 26 2021)  979-8463514271
#
#                                                   link  \
# 371  /gp/slredirect/picassoRedirect.html/ref=pa_sp_...
# 802  /Python-Data-Analysis-Beginners-Fundamentals/d...
#
# ...

# %%
ml_books = dataset[dataset['title'].str.contains('Machine learning')]
ml_books
# Best machine learning books with respect to number of reviews and average reviews.
best_mlbook = ml_books.nlargest(7, ['n_reviews', 'avg_reviews'])
best_mlbook
# Out:
#                                                  title            author  \
# 630  Python for Data Science: 2 Books in 1. A Pract...  [ERICK THOMPSON]
#
#      price  pages  avg_reviews  n_reviews  star5  star4  star3  star2  star1  \
# 630  24.99  265.0          3.5         18    0.6   0.08   0.33    0.0    0.0
#
#              dimensions       weight language  \
# 630  6 x 0.6 x 9 inches  12.6 ounces  English
#
#                                      publisher         ISBN_13  \
# 630  Independently published (October 27 2020)  979-8554509728
#
#                                                   link  \
# 630  /sspa/click?ie=UTF8&spc=MTo1MzAxOTQ0NzI0MTIzNz...
#
#                                          complete_link
# 630  https://www.amazon.com/sspa/click?ie=UTF8&spc=...

# %%
dataset.isnull().any()  #To find the na/nan.
# Out:
# title            False
# author            True
# price             True
# pages             True
# avg_reviews       True
# n_reviews        False
# star5            False
# star4            False
# star3            False
# star2            False
# star1            False
# dimensions        True
# weight            True
# language          True
# publisher         True
# ISBN_13           True
# link             False
# complete_link    False
# dtype: bool

# %%
dataset.replace(np.nan, 0)  #Replace the na/nan with 0.
# Out:
#                                                  title  \
# 0    Becoming a Data Head: How to Think Speak and U...
# 1    Ace the Data Science Interview: 201 Real Inter...
# 2    Fundamentals of Data Engineering: Plan and Bui...
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 0          [Alex J. Gutman,Jordan Goldmeier]   24.49  272.0          4.6
# 1                     [Nick Singh,Kevin Huo]   26.00  301.0          4.5
# 2                    [Joe Reis,Matt Housley]   50.76  446.0          5.0
# ...

# %%
#To deal with with missing values.
dataset.dropna( axis= 0,how = 'any', inplace = True)        #axis = 0, (default) how = any, inplace = True (default -false)
dataset
# Out:
#                                                  title  \
# 0    Becoming a Data Head: How to Think Speak and U...
# 1    Ace the Data Science Interview: 201 Real Inter...
# 2    Fundamentals of Data Engineering: Plan and Bui...
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 0          [Alex J. Gutman,Jordan Goldmeier]   24.49  272.0          4.6
# 1                     [Nick Singh,Kevin Huo]   26.00  301.0          4.5
# 2                    [Joe Reis,Matt Housley]   50.76  446.0          5.0
# ...

# %%
dataset.columns
# Out:
# Index(['title', 'author', 'price', 'pages', 'avg_reviews', 'n_reviews',
#        'star5', 'star4', 'star3', 'star2', 'star1', 'dimensions', 'weight',
#        'language', 'publisher', 'ISBN_13', 'link', 'complete_link'],
#       dtype='object')

# %% [markdown]
# # Let's explore our dataset.
#
#
# *   Which book (title) recieved max reviews?
# *   Which book has most percentage of 5 stars?
# *   Which publisher is most famous?
# *   Which language is most preffered by readers?
# *   What are the average number of pages in a data science book and the costliest book?

# %% [markdown]
# **1. Which book (title) recieved max reviews?**

# %%
max_reviews = dataset['n_reviews'].max() 
review_book = dataset.loc[dataset['n_reviews'] == max_reviews, 'title'].iloc[0]
print(review_book, 'is the most reviewed book with max ', max_reviews, 'reviews')
# Out:
# Cracking the Coding Interview: 189 Programming Questions and Solutions is the most reviewed book with max  7563 reviews

# %% [markdown]
# **2. Which book has most percentage of 5 stars?**

# %%
five_star = dataset['star5'].max()
five_star_book = dataset.loc[dataset['star5'] == five_star, 'title'].iloc[0]


print(five_star_book, ' got most percentage of 5 stars (', five_star, ')')
# Out:
# Effective Data Science Infrastructure: How to make data scientists productive  got most percentage of 5 stars ( 1.0 )

# %%
# Let's find out the number of reviews 
n_reviews_five_star_book = dataset.loc[dataset['title'] == five_star_book, 'n_reviews'].iloc[0]
print(five_star_book, 'got ',n_reviews_five_star_book, ' reviews out of which 5 stars were ', five_star )
# Out:
# Effective Data Science Infrastructure: How to make data scientists productive got  5  reviews out of which 5 stars were  1.0

# %%
maximum_reviews = dataset['n_reviews'].max()
five_star_on_max_n_reviews_book = dataset.loc[dataset['title'] == review_book, 'star5'].iloc[0]
print(review_book, 'got', five_star_on_max_n_reviews_book, 'percent of 5 stars and ', maximum_reviews, 'reviews')
# Out:
# Cracking the Coding Interview: 189 Programming Questions and Solutions got 0.81 percent of 5 stars and  7563 reviews

# %% [markdown]
# **3. Which publisher is most famous?**

# %%
# Authors vs n_reviews (max and min)
most_reviewed = dataset['n_reviews'].max()
star_author = dataset.loc[dataset['n_reviews'] == most_reviewed, 'author'].iloc[0]

print(star_author, ' got maximum number of reviews (', most_reviewed, ')')
# Out:
# [Gayle Laakmann McDowell]  got maximum number of reviews ( 7563 )

# %%
least_reviewed = dataset['n_reviews'].min()
_author = dataset.loc[dataset['n_reviews'] == least_reviewed, 'author'].iloc[0]

print(_author, ' got least number of reviews (', least_reviewed, ')')
# Out:
# [Jordan Morrow]  got least number of reviews ( 1 )

# %% [markdown]
#  **4. Which language is most preffered by readers?**

# %%
dataset['language'].unique()
# Out:
# array(['English', 'Spanish'], dtype=object)

# %%
preffer_language = dataset['language'].value_counts()
preffer_language
# Out:
# English    697
# Spanish      1
# Name: language, dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.bar(preffer_language.index,preffer_language)
plt.show()

# %% [markdown]
# **It is clearing observe that english is the most prefferable language**

# %% [markdown]
#  **5. What are the average number of pages in a data science book and the costliest book?**

# %%
average_no_pages = dataset['pages'].mean().round()    # round function is used to roundoff the value.
print('Average pages per book are - ',average_no_pages)
# Out:
# Average pages per book are -  430.0

# %%
costliest = dataset['price'].max()
costliest_book = dataset.loc[dataset['price'] == costliest, 'title'].iloc[0]

print(costliest_book, 'is the costliest book priced at $', costliest)
# Out:
# Using SPSS for Windows and Macintosh (7th Edition) is the costliest book priced at $ 279.95

# %%
least_cost = dataset['price'].min()
least_costliest_book = dataset.loc[dataset['price'] == least_cost, 'title'].iloc[0]

print(least_costliest_book, 'is the cheapest book priced at $', least_cost)
# Out:
# How to Work With Probability and Statistics Grades 6-8 (Math How To...) is the cheapest book priced at $ 8.99

# %%
ratings = dataset.loc[:,['star5', 'star4', 'star3', 'star2', 'star1']]
ratings
# Out:
#      star5  star4  star3  star2  star1
# 0     0.74   0.18   0.05   0.02   0.01
# 1     0.77   0.10   0.06   0.03   0.04
# 2     0.96   0.04   0.00   0.00   0.00
# 3     0.79   0.05   0.05   0.05   0.05
# 4     0.71   0.15   0.08   0.03   0.03
# ..     ...    ...    ...    ...    ...
# 941   0.74   0.16   0.06   0.02   0.03
# 942   0.70   0.11   0.19   0.00   0.00
# 943   0.72   0.14   0.07   0.01   0.05
# 944   0.78   0.13   0.04   0.02   0.04
# 945   0.69   0.18   0.08   0.03   0.03
#
# [698 rows x 5 columns]

# %%
mean_of_ratings = ratings.mean()
mean_of_ratings
# Out:
# star5    0.719140
# star4    0.162020
# star3    0.067049
# star2    0.030444
# star1    0.021261
# dtype: float64

# %%
#Relationship between Number of Review and Cost of the book
import seaborn as sns 
sns.set(style ="darkgrid")
sns.relplot(x ="n_reviews", y ="price", data = dataset,color='brown');

# %% [markdown]
# This shows that the more no. of reviews does not mean max price
